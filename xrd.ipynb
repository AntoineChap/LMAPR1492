# %%
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifWriter
from IPython.display import FileLink
from pymatgen.analysis.diffraction.xrd import XRDCalculator

# %%
key = "xFkmtLT8p034lKKT"
material = "mp-961682"
m = MPRester(key)
s = m.get_structure_by_material_id(material,conventional_unit_cell=True)
doc = CifWriter(s)
doc.write_file(material+".cif")
display(FileLink(material+".cif"))
# Out:
# /home/users/a/c/achapaux/mp-961682.cif

# %%
xrd = XRDCalculator(1.54060) #Création XRDCalculator
dif = xrd.get_pattern(s) #Calcul de la diffraction
xrd.show_plot(s,annotate_peaks=False,two_theta_range=[0,180])

for i in range(3): #Détermination des 3 premiers pics
    print("Pic n° "+str(i+1) + " : ")
    print("Angle = "+str(dif.x[i]))
    print("Intensité = "+str(dif.y[i]))
    print("Indices hkl = "+str(dif.hkls[i][0]["hkl"]))
    print("Multiplicité = "+str(dif.hkls[i][0]["multiplicity"]))
    print(" ")
# Out:
# Pic n° 1 :
# Angle = 24.793806447622934
# Intensité = 56.405108776331815
# Indices hkl = (1, 1, 1)
# Multiplicité = 8
#
# Pic n° 2 :
# Angle = 28.70585484964075
# Intensité = 6.247527193547421
# Indices hkl = (2, 0, 0)
# Multiplicité = 6
#
# Pic n° 3 :
# Angle = 41.044991825990046
# Intensité = 100.0
# Indices hkl = (2, 2, 0)
# Multiplicité = 12
